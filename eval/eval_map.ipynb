# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import numpy as np
import skimage.io as io
import pylab 
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
annType = 'bbox'
prefix = 'instances'
dataDir = '/home/project_oliv/OLIV/training/data'
annFile = '%s/subsetCOCO_test_gt.json' %(dataDir)
cocoGt = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!

# %%
resFile = 'subsetCOCO_testRes_1_192.json'
cocoDt = cocoGt.loadRes(resFile)
# Out:
# Loading and preparing results...
# DONE (t=0.26s)
# creating index...
# index created!

# %%
imgIds = sorted(cocoGt.getImgIds())
cocoEval = COCOeval(cocoGt,cocoDt, annType)
cocoEval.params.imgIds = imgIds
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.28s).
# Accumulating evaluation results...
# DONE (t=2.25s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
# ...

# %%
def reverse_dict(dict2reverse):
    rev_dict = {}
    for key in dict2reverse:
        rev_dict[dict2reverse[key]] = key
    return rev_dict

# %%
'''class_labels = {'bottle': 44, 'person': 1, 'backpack': 27, 'handbag': 31, 
                'umbrella': 28, 'bowl': 51, 'cup': 47, 'clock': 85, 
                'knife': 49, 'spoon': 50, 'fork': 48, 'chair': 62, 
                'potted plant': 64, 'dining table': 67, 'keyboard': 76, 'mouse': 74, 
                'laptop': 73, 'cell phone': 77, 'scissors': 87, 'book': 84, 'monitor': 72}'''
class_labels = {'bottle': 1, 'person': 2, 'backpack': 3, 'handbag': 4, 
                'umbrella': 5, 'bowl': 6, 'cup': 7, 'clock': 8, 
                'knife': 9, 'spoon': 10, 'fork': 11, 'chair': 12, 
                'potted plant': 13, 'dining table': 14, 'keyboard': 15, 'mouse': 16, 
                'laptop': 17, 'cell phone': 18, 'scissors': 19, 'book': 20, 'monitor': 21}
labels_class = reverse_dict(class_labels)
print(labels_class)
# Out:
# {1: 'bottle', 2: 'person', 3: 'backpack', 4: 'handbag', 5: 'umbrella', 6: 'bowl', 7: 'cup', 8: 'clock', 9: 'knife', 10: 'spoon', 11: 'fork', 12: 'chair', 13: 'potted plant', 14: 'dining table', 15: 'keyboard', 16: 'mouse', 17: 'laptop', 18: 'cell phone', 19: 'scissors', 20: 'book', 21: 'monitor'}

# %%
catIds = sorted(cocoGt.getCatIds())
cocoEval = COCOeval(cocoGt,cocoDt, annType)
for catId in catIds:
    print("Category %s results: " % labels_class[catId])
    cocoEval.params.catIds = catId
    cocoEval.evaluate()
    cocoEval.accumulate()
    cocoEval.summarize()
# Out:
# Category bottle results:
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.53s).
# Accumulating evaluation results...
# DONE (t=0.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.004
# ...
